# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
DATAFILE = 'preprocessed_data.csv'

# %%
df = pd.read_csv(DATAFILE)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5902 entries, 0 to 5901
# Columns: 160 entries, Winner to R_Stance_Switch
# dtypes: bool(1), float64(106), int64(52), object(1)
# memory usage: 7.2+ MB

# %%
df_numeric = df.select_dtypes(include='number')
df_numeric.fillna(0, inplace=True)
df_categorical = df.select_dtypes(exclude='number')

# %%
df_numeric.describe()
# Out:
#           B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  B_avg_opp_SIG_STR_pct  \
# count  5902.000000   5902.000000        5902.000000            5902.000000
# mean      0.193739      0.135246           0.452788               0.432788
# std       0.346475      0.294238           0.114325               0.116189
# min       0.000000      0.000000           0.000000               0.000000
# 25%       0.000000      0.000000           0.401611               0.376250
# 50%       0.015625      0.000000           0.450000               0.427500
# 75%       0.250000      0.093750           0.500000               0.480000
# max       5.000000      3.000000           1.000000               1.000000
#
#        B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  B_avg_opp_SUB_ATT  \
# count   5902.000000       5902.000000    5902.000000        5902.000000
# mean       0.282610          0.252897       0.400956           0.335873
# std        0.239811          0.235253       0.648117           0.586483
# min        0.000000          0.000000       0.000000           0.000000
# 25%        0.100000          0.082733       0.000000           0.000000
# 50%        0.250000          0.200000       0.148468           0.098389
# 75%        0.395828          0.330000       0.500000           0.500000
# max        1.000000          1.000000       8.000000           7.000000
#
#          B_avg_REV  B_avg_opp_REV  ...  B_Stance_Open Stance  \
# count  5902.000000    5902.000000  ...           5902.000000
# mean      0.120343       0.108563  ...              0.001525
# std       0.307538       0.289504  ...              0.039024
# min       0.000000       0.000000  ...              0.000000
# 25%       0.000000       0.000000  ...              0.000000
# 50%       0.000000       0.000000  ...              0.000000
# 75%       0.031250       0.007820  ...              0.000000
# max       4.000000       3.000000  ...              1.000000
#
#        B_Stance_Orthodox  B_Stance_Sideways  B_Stance_Southpaw  \
# count        5902.000000        5902.000000        5902.000000
# mean            0.764825           0.000678           0.193155
# std             0.424144           0.026027           0.394807
# min             0.000000           0.000000           0.000000
# 25%             1.000000           0.000000           0.000000
# 50%             1.000000           0.000000           0.000000
# 75%             1.000000           0.000000           0.000000
# max             1.000000           1.000000           1.000000
#
#        B_Stance_Switch  R_Stance_Open Stance  R_Stance_Orthodox  \
# count      5902.000000           5902.000000        5902.000000
# mean          0.039817              0.002542           0.759065
# std           0.195546              0.050354           0.427687
# min           0.000000              0.000000           0.000000
# 25%           0.000000              0.000000           1.000000
# 50%           0.000000              0.000000           1.000000
# 75%           0.000000              0.000000           1.000000
# max           1.000000              1.000000           1.000000
#
#        R_Stance_Sideways  R_Stance_Southpaw  R_Stance_Switch
# count        5902.000000        5902.000000      5902.000000
# mean            0.000339           0.205015         0.033040
# std             0.018407           0.403747         0.178755
# min             0.000000           0.000000         0.000000
# 25%             0.000000           0.000000         0.000000
# 50%             0.000000           0.000000         0.000000
# 75%             0.000000           0.000000         0.000000
# max             1.000000           1.000000         1.000000
#
# [8 rows x 158 columns]

# %%
df_categorical.describe()
# Out:
#        Winner title_bout
# count    5902       5902
# unique      2          2
# top       Red      False
# freq     3979       5542

# %%
df_numeric.corr()
# Out:
#                        B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  \
# B_avg_KD               1.000000     -0.024267           0.134106
# B_avg_opp_KD          -0.024267      1.000000          -0.125035
# B_avg_SIG_STR_pct      0.134106     -0.125035           1.000000
# B_avg_opp_SIG_STR_pct -0.143944      0.189852          -0.037552
# B_avg_TD_pct          -0.080119     -0.066919           0.155344
# ...                         ...           ...                ...
# R_Stance_Open Stance  -0.003821      0.003001          -0.017572
# R_Stance_Orthodox     -0.000807     -0.001065           0.014917
# R_Stance_Sideways     -0.009466     -0.008463          -0.000449
# R_Stance_Southpaw      0.006558      0.007700          -0.019028
# R_Stance_Switch       -0.010830     -0.014816           0.012285
#
#                        B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  \
# B_avg_KD                           -0.143944     -0.080119         -0.122033
# B_avg_opp_KD                        0.189852     -0.066919         -0.012839
# B_avg_SIG_STR_pct                  -0.037552      0.155344         -0.085845
# B_avg_opp_SIG_STR_pct               1.000000     -0.112853          0.211172
# B_avg_TD_pct                       -0.112853      1.000000         -0.140537
# ...                                      ...           ...               ...
# R_Stance_Open Stance                0.013033     -0.010274          0.018507
# R_Stance_Orthodox                   0.005764     -0.000379         -0.021671
# R_Stance_Sideways                  -0.000838     -0.002504         -0.004140
# R_Stance_Southpaw                  -0.017982     -0.005776          0.026421
# R_Stance_Switch                     0.023241      0.017104         -0.012614
#
#                        B_avg_SUB_ATT  B_avg_opp_SUB_ATT  B_avg_REV  \
# B_avg_KD                   -0.064387          -0.034044  -0.022072
# B_avg_opp_KD               -0.019710           0.002549   0.012745
# B_avg_SIG_STR_pct           0.060614          -0.002520   0.027763
# B_avg_opp_SIG_STR_pct       0.010273           0.095166   0.053195
# B_avg_TD_pct                0.192377           0.112330   0.065047
# ...                              ...                ...        ...
# R_Stance_Open Stance        0.027020           0.006883   0.027043
# R_Stance_Orthodox          -0.004477          -0.033425  -0.014327
# R_Stance_Sideways          -0.007173          -0.007456  -0.007205
# R_Stance_Southpaw           0.018548           0.044839   0.021505
# R_Stance_Switch            -0.038054          -0.022476  -0.021171
#
#                        B_avg_opp_REV  ...  B_Stance_Open Stance  \
# B_avg_KD                   -0.036925  ...              0.002821
# B_avg_opp_KD                0.006039  ...             -0.006895
# B_avg_SIG_STR_pct           0.009683  ...             -0.006313
# B_avg_opp_SIG_STR_pct       0.044557  ...             -0.014977
# B_avg_TD_pct                0.209581  ...             -0.022914
# ...                              ...  ...                   ...
# R_Stance_Open Stance       -0.000596  ...             -0.001973
# R_Stance_Orthodox          -0.015679  ...             -0.028751
# R_Stance_Sideways          -0.006905  ...              0.235203
# R_Stance_Southpaw           0.020108  ...              0.023177
# R_Stance_Switch            -0.007024  ...             -0.007224
#
#                        B_Stance_Orthodox  B_Stance_Sideways  \
# B_avg_KD                       -0.042550           0.000118
# B_avg_opp_KD                    0.031507          -0.011971
# B_avg_SIG_STR_pct              -0.026937           0.010043
# B_avg_opp_SIG_STR_pct           0.010551          -0.027524
# B_avg_TD_pct                   -0.014525          -0.017117
# ...                                  ...                ...
# R_Stance_Open Stance            0.012121          -0.001315
# R_Stance_Orthodox               0.026701          -0.000552
# R_Stance_Sideways              -0.011497          -0.000479
# R_Stance_Southpaw              -0.023195           0.002902
# R_Stance_Switch                -0.013726          -0.004814
#
#                        B_Stance_Southpaw  B_Stance_Switch  \
# B_avg_KD                        0.032446         0.026206
# B_avg_opp_KD                   -0.014240        -0.036618
# B_avg_SIG_STR_pct               0.014994         0.028077
# B_avg_opp_SIG_STR_pct          -0.014526         0.013095
# B_avg_TD_pct                    0.031870        -0.025990
# ...                                  ...              ...
# R_Stance_Open Stance           -0.007649        -0.010279
# R_Stance_Orthodox              -0.026429         0.001256
# R_Stance_Sideways              -0.009008        -0.003749
# R_Stance_Southpaw               0.022626        -0.000383
# R_Stance_Switch                 0.015211         0.001143
#
#                        R_Stance_Open Stance  R_Stance_Orthodox  \
# B_avg_KD                          -0.003821          -0.000807
# B_avg_opp_KD                       0.003001          -0.001065
# B_avg_SIG_STR_pct                 -0.017572           0.014917
# B_avg_opp_SIG_STR_pct              0.013033           0.005764
# B_avg_TD_pct                      -0.010274          -0.000379
# ...                                     ...                ...
# R_Stance_Open Stance               1.000000          -0.089596
# R_Stance_Orthodox                 -0.089596           1.000000
# R_Stance_Sideways                 -0.000929          -0.032680
# R_Stance_Southpaw                 -0.025634          -0.901370
# R_Stance_Switch                   -0.009331          -0.328097
#
#                        R_Stance_Sideways  R_Stance_Southpaw  R_Stance_Switch
# B_avg_KD                       -0.009466           0.006558        -0.010830
# B_avg_opp_KD                   -0.008463           0.007700        -0.014816
# B_avg_SIG_STR_pct              -0.000449          -0.019028         0.012285
# B_avg_opp_SIG_STR_pct          -0.000838          -0.017982         0.023241
# B_avg_TD_pct                   -0.002504          -0.005776         0.017104
# ...                                  ...                ...              ...
# R_Stance_Open Stance           -0.000929          -0.025634        -0.009331
# R_Stance_Orthodox              -0.032680          -0.901370        -0.328097
# R_Stance_Sideways               1.000000          -0.009350        -0.003403
# R_Stance_Southpaw              -0.009350           1.000000        -0.093870
# R_Stance_Switch                -0.003403          -0.093870         1.000000
#
# [158 rows x 158 columns]

# %%
sns.color_palette('coolwarm')
sns.set_style('whitegrid')
sns.pairplot(df_numeric)
